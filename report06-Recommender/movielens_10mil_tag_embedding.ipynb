# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Embedding the tags

# %% [markdown]
# ## Load tags

# %%
tags_df = pd.read_table("ml-10M100K/tags.dat", sep="::", names=["userId", "movieId", "tag", "timestamp"])
# Out:
# <ipython-input-2-40267eb68d8e>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   tags_df = pd.read_table("ml-10M100K/tags.dat", sep="::", names=["userId", "movieId", "tag", "timestamp"])

# %%
tags_df.head()
# Out:
#    userId  movieId              tag   timestamp
# 0      15     4973       excellent!  1215184630
# 1      20     1747         politics  1188263867
# 2      20     1747           satire  1188263867
# 3      20     2424  chick flick 212  1188263835
# 4      20     2424            hanks  1188263835

# %%
tags_df.drop(["userId", "timestamp"], axis=1, inplace=True)

# %%
tags_df.head()
# Out:
#    movieId              tag
# 0     4973       excellent!
# 1     1747         politics
# 2     1747           satire
# 3     2424  chick flick 212
# 4     2424            hanks

# %%
tags_df["tag"] = tags_df["tag"].astype(str)
tags_df["tag"] = tags_df.groupby("movieId")["tag"].transform(lambda x: ' '.join(x))
tags_df.drop_duplicates(inplace=True)

# %%
tags_df.sort_values(by="movieId", axis=0, inplace=True)
tags_df.reset_index(drop=True, inplace=True)
tags_df.head()
# Out:
#    movieId                                                tag
# 0        1  Pixar Pixar Pixar animation Pixar animated fun...
# 1        2  For children game animals Joe Johnston Robin W...
# 2        3  Funniest Movies comedinha de velhinhos engra̤...
# 3        4                                         girl movie
# 4        5  steve martin pregnancy remake steve martin fam...

# %%
from sklearn.model_selection import train_test_split
tags_train_df, tags_test_df = train_test_split(tags_df, test_size=0.1)

# %%
tags_test_df.shape
# Out:
# (761, 2)

# %% [markdown]
# ## Vectorizing the Tags

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,1))
X_train_tags = vectorizer.fit_transform(tags_train_df["tag"])

# %%
X_train_tags.shape
# Out:
# (6840, 11352)

# %% [markdown]
# ## Auto Encoder

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, InputLayer, Dropout, BatchNormalization
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-13-10b6e303d04b>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
tags_auto_encoder = keras.models.Sequential()
hidden_units = [3000, 1000, 500, 200, 500, 1000, 3000]
tags_auto_encoder.add(InputLayer(X_train_tags.shape[1]))
tags_auto_encoder.add(BatchNormalization())
tags_auto_encoder.add(Dropout(0.2))
for u in hidden_units:
    tags_auto_encoder.add(Dense(u, activation="relu"))
    tags_auto_encoder.add(BatchNormalization())
    tags_auto_encoder.add(Dropout(0.3))
tags_auto_encoder.add(Dense(X_train_tags.shape[1]))

# %%
tags_auto_encoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_10 (Batc (None, 11352)             45408
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 11352)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3000)              34059000
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 3000)              12000
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 3000)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1000)              3001000
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 1000)              4000
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 500)               500500
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 500)               2000
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 200)               100200
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 200)               800
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 200)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 500)               100500
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 500)               2000
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 500)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1000)              501000
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 1000)              4000
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1000)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 3000)              3003000
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 3000)              12000
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 3000)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 11352)             34067352
# =================================================================
# Total params: 75,414,760
# Trainable params: 75,373,656
# Non-trainable params: 41,104
# _________________________________________________________________

# %%
tags_auto_encoder.compile(optimizer=keras.optimizers.Nadam(), loss=keras.losses.MSE, metrics=[keras.metrics.mse])

# %%
tags_auto_encoder.save_weights("init_weights_tags_auto_encoder.h5")

# %%
from livelossplot import PlotLossesKerasTF
import tensorboard

# %%
import time
import os
def get_board_path(name: str = ""):
    return os.path.join(".", "tensorboard", time.strftime("%Y-%m-%d_%H:%M:%S", time.gmtime())+"_"+ name)

# %%
# loss_plot_cb = PlotLossesKerasTF()
early_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
tensorboard_cb = keras.callbacks.TensorBoard(log_dir=get_board_path("tags_ae"))

# %%
tags_auto_encoder.fit(x=X_train_tags.todense(), y=X_train_tags.todense(), batch_size=16, epochs=30, callbacks=[early_cb, tensorboard_cb], validation_split=0.07, shuffle=True)
# Out:
# Epoch 1/30
# 398/398 [==============================] - 134s 331ms/step - loss: 0.3395 - mean_squared_error: 0.3395 - val_loss: 0.0693 - val_mean_squared_error: 0.0693
# Epoch 2/30
# 398/398 [==============================] - 131s 328ms/step - loss: 0.0604 - mean_squared_error: 0.0604 - val_loss: 0.0567 - val_mean_squared_error: 0.0567
# Epoch 3/30
# 398/398 [==============================] - 131s 329ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 4/30
# 398/398 [==============================] - 131s 329ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 5/30
# 398/398 [==============================] - 131s 330ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 6/30
# 398/398 [==============================] - 131s 329ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 7/30
# 398/398 [==============================] - 131s 330ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 8/30
# 398/398 [==============================] - 131s 330ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 9/30
# 398/398 [==============================] - 131s 329ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 10/30
# 398/398 [==============================] - 131s 330ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 11/30
# 398/398 [==============================] - 132s 330ms/step - loss: 8.9122e-04 - mean_squared_error: 8.9122e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 12/30
# 398/398 [==============================] - 132s 332ms/step - loss: 5.9918e-04 - mean_squared_error: 5.9918e-04 - val_loss: 6.9866e-04 - val_mean_squared_error: 6.9866e-04
# Epoch 13/30
# 398/398 [==============================] - 132s 330ms/step - loss: 4.3933e-04 - mean_squared_error: 4.3933e-04 - val_loss: 5.8415e-04 - val_mean_squared_error: 5.8415e-04
# Epoch 14/30
# 398/398 [==============================] - 132s 331ms/step - loss: 3.4771e-04 - mean_squared_error: 3.4771e-04 - val_loss: 3.9403e-04 - val_mean_squared_error: 3.9403e-04
# Epoch 15/30
# 398/398 [==============================] - 132s 332ms/step - loss: 2.8571e-04 - mean_squared_error: 2.8571e-04 - val_loss: 3.8038e-04 - val_mean_squared_error: 3.8038e-04
# Epoch 16/30
# 398/398 [==============================] - 132s 332ms/step - loss: 2.3349e-04 - mean_squared_error: 2.3349e-04 - val_loss: 2.8274e-04 - val_mean_squared_error: 2.8274e-04
# Epoch 17/30
# 398/398 [==============================] - 132s 333ms/step - loss: 1.9134e-04 - mean_squared_error: 1.9134e-04 - val_loss: 2.3971e-04 - val_mean_squared_error: 2.3971e-04
# Epoch 18/30
# 398/398 [==============================] - 133s 334ms/step - loss: 1.5935e-04 - mean_squared_error: 1.5935e-04 - val_loss: 1.8027e-04 - val_mean_squared_error: 1.8027e-04
# Epoch 19/30
# 398/398 [==============================] - 133s 335ms/step - loss: 1.3704e-04 - mean_squared_error: 1.3704e-04 - val_loss: 1.5358e-04 - val_mean_squared_error: 1.5358e-04
# Epoch 20/30
# 398/398 [==============================] - 132s 331ms/step - loss: 1.1978e-04 - mean_squared_error: 1.1978e-04 - val_loss: 1.2802e-04 - val_mean_squared_error: 1.2802e-04
# Epoch 21/30
# 398/398 [==============================] - 132s 331ms/step - loss: 1.0720e-04 - mean_squared_error: 1.0720e-04 - val_loss: 1.0610e-04 - val_mean_squared_error: 1.0610e-04
# Epoch 22/30
# 398/398 [==============================] - 132s 331ms/step - loss: 9.7898e-05 - mean_squared_error: 9.7898e-05 - val_loss: 9.8286e-05 - val_mean_squared_error: 9.8286e-05
# Epoch 23/30
# 398/398 [==============================] - 131s 329ms/step - loss: 9.0895e-05 - mean_squared_error: 9.0895e-05 - val_loss: 9.0550e-05 - val_mean_squared_error: 9.0550e-05
# Epoch 24/30
# 398/398 [==============================] - 131s 329ms/step - loss: 8.6667e-05 - mean_squared_error: 8.6667e-05 - val_loss: 8.6240e-05 - val_mean_squared_error: 8.6240e-05
# Epoch 25/30
# 398/398 [==============================] - 131s 329ms/step - loss: 8.5084e-05 - mean_squared_error: 8.5084e-05 - val_loss: 8.4409e-05 - val_mean_squared_error: 8.4409e-05
# Epoch 26/30
# 398/398 [==============================] - 131s 329ms/step - loss: 8.4079e-05 - mean_squared_error: 8.4079e-05 - val_loss: 8.3877e-05 - val_mean_squared_error: 8.3877e-05
# Epoch 27/30
# 398/398 [==============================] - 132s 331ms/step - loss: 8.3786e-05 - mean_squared_error: 8.3786e-05 - val_loss: 8.3617e-05 - val_mean_squared_error: 8.3617e-05
# Epoch 28/30
# 398/398 [==============================] - 132s 331ms/step - loss: 8.3764e-05 - mean_squared_error: 8.3764e-05 - val_loss: 8.3482e-05 - val_mean_squared_error: 8.3482e-05
# Epoch 29/30
# 398/398 [==============================] - 132s 331ms/step - loss: 8.3511e-05 - mean_squared_error: 8.3511e-05 - val_loss: 8.3569e-05 - val_mean_squared_error: 8.3569e-05
# Epoch 30/30
# 398/398 [==============================] - 132s 331ms/step - loss: 8.3466e-05 - mean_squared_error: 8.3466e-05 - val_loss: 8.3174e-05 - val_mean_squared_error: 8.3174e-05

# %%
X_test = vectorizer.transform(tags_test_df["tag"])
tags_auto_encoder.evaluate(X_test.todense(), X_test.todense())
# Out:
# 24/24 [==============================] - 0s 15ms/step - loss: 8.1994e-05 - mean_squared_error: 8.1994e-05
# [8.19939814391546e-05, 8.19939814391546e-05]

# %%
tags_auto_encoder.save("movielens10_tags_embedding/auto_encoder")
# Out:
# INFO:tensorflow:Assets written to: movielens10_tags_embedding/auto_encoder/assets

# %%
tags_df.to_pickle("movielens10_tags_embedding/tags_all.pkl")
tags_test_df.to_pickle("movielens10_tags_embedding/tags_test.pkl")
tags_train_df.to_pickle("movielens10_tags_embedding/tags_train.pkl")

# %%
from joblib import dump, load
dump(vectorizer, "movielens10_tags_embedding/vectorizer.joblib")
# Out:
# ['movielens10_tags_embedding/vectorizer.joblib']
